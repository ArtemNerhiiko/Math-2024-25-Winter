# %% [markdown]
# ![Screenshot 2024-12-12 004447.png](data:image/png;base64,...)

# %%
#1 Compute:

# %% [markdown]
# ![Screenshot 2024-12-12 005509.png](data:image/png;base64,...)

# %%
#2 Find:

# %% [markdown]
# ![Screenshot 2024-12-12 005736.png](data:image/png;base64,...)

# %%
#3 Find the asymptotes of the function:
