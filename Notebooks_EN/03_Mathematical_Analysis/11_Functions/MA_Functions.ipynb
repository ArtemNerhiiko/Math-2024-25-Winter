# %% [markdown]
# 1. Draw in a single Geogebra notebook the following functions:
#    - $f(x) = x^2$
#    - $g(x) = \sqrt{x}$
#    - $h(x) = \frac{1}{x}$
#    - $j(x) = \sin(x)$
#
# Find value of all the above functions at $x = 2$.
#
# 2. Let $f(x) = 3x - 1$ and $g(x) = \sqrt{x}$. Find:
#    - $f(g(x))$
#    - $g(f(x))$
#    - $f(f(x))$
#    - $g(g(x))$
#
# and visualize functions in a single Geogebra notebook.
#
# 3. Let $f(x) = e^x$ and $g(x) = \ln(x)$. Check: $f(g(x))$ and $g(f(x))$. What do you notice?
#
# 4. We have function $f=\{(1,7), (2,9), (3,11)\}$. Give inverse function $f^{-1}$.
#
# 5. We have function $f=\{(1,7), (2,7), (3,11)\}$. Give inverse function $f^{-1}$.
#
# 6. We have function $f(x)= x-1$. Give inverse function $f^{-1}$. Show both functions on the same Geogebra notebook.

# %% [markdown]
# ##1. Draw in a single Geogebra notebook the following functions:
#    - $f(x) = x^2$
#    - $g(x) = \sqrt{x}$
#    - $h(x) = \frac{1}{x}$
#    - $j(x) = \sin(x)$

# %% [markdown]
# Find value of all the above functions at $x = 2$.
#
# 1. For $f(x) = x^2$
#
# $f(2) = 2^2 = 4$
#
# 2. For $g(x) = \sqrt{x}$
#
# $g(x) = \sqrt{2} = 1.414$
#
# 3. For $h(x) = \frac{1}{x}$
#
# $h(2) = \frac{1}{2} = 0.5$
#
# 4. For $j(x) = sin(x)$
#
# $j(2) = sin(2) = 0.909$

# %% [markdown]
# ![Screenshot 2025-01-30 031359.png](data:image/png;base64,...)

# %% [markdown]
# 2. Let $f(x) = 3x - 1$ and $g(x) = \sqrt{x}$. Find:
#    - $f(g(x))$
#    - $g(f(x))$
#    - $f(f(x))$
#    - $g(g(x))$
#
# and visualize functions in a single Geogebra notebook.

# %% [markdown]
# ![Screenshot 2024-12-11 213648.png](data:image/png;base64,...)

# %%
#Let f ( x ) = e x and g ( x ) = ln ⁡ ( x ) . Check: f ( g ( x ) ) and g ( f ( x ) ) . What do you notice?

# %% [markdown]
# ![Screenshot 2024-12-11 213907.png](data:image/png;base64,...)

# %%
#We have function f = ( 1 , 7 ) , ( 2 , 9 ) , ( 3 , 11 ) . Give inverse function f^-1
#Steps to Find the Inverse
#Swap the coordinates: In the original function, each point is represented as (x, y). To find the inverse, swap the x and y values to get (y, x).
#Write the inverse function: Using the swapped coordinates, you can now define the inverse function f^-1.
#Therefore, the inverse function f^-1 is {(7, 1), (9, 2), (11, 3)}.

# %%
#We have function f = ( 1 , 7 ) , ( 2 , 7 ) , ( 3 , 11 ) . Give inverse function f^-1 .
#However, note that for f^-1 to be a proper function, each input in f^-1 must have exactly one output. Here, 7 maps to both 1 and 2 which violates the definition of a function.
#So, f^-1 is not a valid function.

# %%
#We have function f(x)=x-1. Give inverse function f^-1. Show both functions on the same Geogebra notebook.

# %% [markdown]
# ![Screenshot 2024-12-11 215025.png](data:image/png;base64,...)
